# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv("D:/Dataset/advertising.csv")

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
data.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
data.isnull()
# Out:
#         TV  Radio  Newspaper  Sales
# 0    False  False      False  False
# 1    False  False      False  False
# 2    False  False      False  False
# 3    False  False      False  False
# 4    False  False      False  False
# ..     ...    ...        ...    ...
# 195  False  False      False  False
# 196  False  False      False  False
# 197  False  False      False  False
# 198  False  False      False  False
# 199  False  False      False  False
#
# [200 rows x 4 columns]

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
data.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
data.shape
# Out:
# (200, 4)

# %%
import matplotlib.pyplot as plt

# %%
sns.relplot(x = 'TV' , y = 'Sales' , data = data)
# Out:
# C:\Users\Thamotharan\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:64: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout(*args, **kwargs)

# %%
sns.relplot(x = 'Radio' , y = 'Newspaper' , hue = 'Sales' , data = data)
# Out:
# C:\Users\Thamotharan\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:64: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout(*args, **kwargs)

# %%
sns.relplot(x = 'TV' , y = 'Radio' , hue = 'Sales' , data = data)
# Out:
# C:\Users\Thamotharan\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:64: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout(*args, **kwargs)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
train=data[['TV','Radio','Newspaper']]
test=data[['Sales']]

# %%
X_train,X_test,y_train,y_test=train_test_split(train,test,test_size=0.2,random_state=10)

# %%
regr=LinearRegression()

# %%
regr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred=regr.predict(X_test)

# %%
pred
# Out:
# array([[19.27102862],
#        [10.48212482],
#        [19.4267087 ],
#        [24.45648335],
#        [20.86340871],
#        [15.25422464],
#        [16.81344896],
#        [20.7374558 ],
#        [21.14142192],
#        [10.61813631],
#        [24.8362031 ],
#        [ 8.92965564],
#        [10.33492854],
#        [20.15938749],
#        [20.49335898],
#        [13.50252635],
#        [21.38558511],
#        [ 8.32591533],
#        [21.83704273],
#        [20.65094605],
#        [17.13013995],
#        [ 9.13181045],
#        [23.35488529],
#        [15.05375263],
#        [20.86139394],
#        [ 8.09385767],
#        [10.39839367],
#        [11.39364194],
#        [22.12834829],
#        [ 8.00815831],
#        [13.7989675 ],
#        [21.05903052],
#        [ 6.41095702],
#        [ 6.44209421],
#        [20.78756344],
#        [19.82135121],
#        [ 9.07317268],
#        [21.15584856],
#        [10.62363975],
#        [17.04930911]])

# %%
regr.score(X_test,y_test)
# Out:
# 0.8886717577059424
